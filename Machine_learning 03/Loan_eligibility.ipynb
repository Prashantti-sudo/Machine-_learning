# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv("/content/loan_eligibility_dataset.csv")

# %%
data
# Out:
#        Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0     LP000001    Male      No          2  Not Graduate           Yes
# 1     LP000002  Female     Yes          2  Not Graduate            No
# 2     LP000003    Male     Yes          2      Graduate           Yes
# 3     LP000004    Male      No          2  Not Graduate            No
# 4     LP000005    Male      No         3+      Graduate            No
# ...        ...     ...     ...        ...           ...           ...
# 2495  LP002496  Female     Yes          2  Not Graduate           Yes
# 2496  LP002497  Female      No          1      Graduate            No
# 2497  LP002498  Female     Yes          2  Not Graduate            No
# 2498  LP002499    Male      No          2  Not Graduate            No
# 2499  LP002500  Female      No          1      Graduate           Yes
#
#       ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
data.drop("Loan_ID",axis=1,inplace=True)

# %%
data
# Out:
#       Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0       Male      No          2  Not Graduate           Yes            17262
# 1     Female     Yes          2  Not Graduate            No            20994
# 2       Male     Yes          2      Graduate           Yes            20050
# 3       Male      No          2  Not Graduate            No            10026
# 4       Male      No         3+      Graduate            No            17398
# ...      ...     ...        ...           ...           ...              ...
# 2495  Female     Yes          2  Not Graduate           Yes             4223
# 2496  Female      No          1      Graduate            No            18542
# 2497  Female     Yes          2  Not Graduate            No             6261
# 2498    Male      No          2  Not Graduate            No             9130
# 2499  Female      No          1      Graduate           Yes            17875
#
# ...

# %%
data.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
data["Dependents"].unique()
# Out:
# array(['2', '3+', '0', '1'], dtype=object)

# %%
data["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             2500 non-null   object
#  1   Married            2500 non-null   object
#  2   Dependents         2500 non-null   object
#  3   Education          2500 non-null   object
#  4   Self_Employed      2500 non-null   object
#  5   ApplicantIncome    2500 non-null   int64
#  6   CoapplicantIncome  2500 non-null   int64
#  7   LoanAmount         2500 non-null   int64
#  8   Loan_Amount_Term   2500 non-null   int64
#  9   Credit_History     2500 non-null   int64
#  10  Property_Area      2500 non-null   object
#  11  Loan_Status        2500 non-null   object
# dtypes: int64(5), object(7)
# memory usage: 234.5+ KB

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
for i in data.columns:
  if data[i].dtype == "object":
    data[i] = lb.fit_transform(data[i])

# %%
x = data.drop("Loan_Status",axis=1)
y = data["Loan_Status"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#       Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 2055       1        0           0          1              0             3471
# 1961       1        1           1          0              0            18340
# 1864       0        1           2          0              1            17605
# 2326       0        0           3          1              1            11551
# 461        1        1           3          0              1             8565
# ...      ...      ...         ...        ...            ...              ...
# 1638       1        1           0          0              0            24707
# 1095       0        1           0          0              0            23786
# 1130       0        0           1          0              1             4189
# 1294       0        1           0          0              1            15246
# 860        0        0           0          0              0            15136
#
# ...

# %%
y_train
# Out:
# 2055    0
# 1961    1
# 1864    1
# 2326    1
# 461     1
#        ..
# 1638    1
# 1095    1
# 1130    0
# 1294    1
# 860     0
# Name: Loan_Status, Length: 2000, dtype: int64

# %%
x_test
# Out:
#       Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 1447       0        1           1          0              1            13378
# 1114       1        0           2          1              1            15892
# 1064       0        1           1          0              0            23274
# 2287       1        1           3          0              1             4392
# 1537       0        0           2          0              0            13406
# ...      ...      ...         ...        ...            ...              ...
# 2375       0        0           1          1              0            24391
# 1609       1        1           2          0              1            17190
# 596        1        0           1          1              0            11087
# 84         1        1           3          1              0            19453
# 2213       1        1           3          0              0            17108
#
# ...

# %%
y_test
# Out:
# 1447    0
# 1114    0
# 1064    1
# 2287    0
# 1537    1
#        ..
# 2375    0
# 1609    0
# 596     1
# 84      0
# 2213    0
# Name: Loan_Status, Length: 500, dtype: int64

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state=42)

# %%
param_grid = {
    'n_estimators': [100, 200, 300],     # Number of trees
    'max_depth': [None, 10, 20, 30],     # Maximum depth of tree
    'min_samples_split': [2, 5, 10],     # Minimum samples to split a node
    'min_samples_leaf': [1, 2, 4],       # Minimum samples in a leaf node
    'max_features': ['sqrt', 'log2']     # Number of features to consider
}

# Grid Search
grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=2,
    n_jobs=-1,
    verbose=2,
    scoring='accuracy'  # or 'f1', 'roc_auc', depending on your goal
)
grid_search.fit(x_train, y_train)
# Out:
# Fitting 2 folds for each of 216 candidates, totalling 432 fits
# GridSearchCV(cv=2, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [None, 10, 20, 30],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300]},
#              scoring='accuracy', verbose=2)

# %%
print("Best Parameters:", grid_search.best_params_)
print("Best Cross-Validation Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# Best Cross-Validation Score: 0.999

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,confusion_matrix

# %%
best_rf = grid_search.best_estimator_
y_pred = best_rf.predict(x_test)
print(classification_report(y_test, y_pred))
aj = confusion_matrix(y_test, y_pred)
print(aj)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       240
#            1       1.00      1.00      1.00       260
#
#     accuracy                           1.00       500
#    macro avg       1.00      1.00      1.00       500
# weighted avg       1.00      1.00      1.00       500
#
# [[240   0]
#  [  0 260]]

# %%
grid_search.predict([[0,	1,	1,	0,	1,	13378,	92,	529,	180	,1,	0]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
# Access the row with index 1447 from the data DataFrame
row_1447 = data.loc[1447]
display(row_1447)
# Out:
# Gender                   0
# Married                  1
# Dependents               1
# Education                0
# Self_Employed            1
# ApplicantIncome      13378
# CoapplicantIncome       92
# LoanAmount             529
# Loan_Amount_Term       180
# Credit_History           1
# Property_Area            0
# Loan_Status              0
# Name: 1447, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = sns.load_dataset("titanic")

# %%
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
data.drop(["alive"],axis =1,inplace = True)

# %%
data.dropna(inplace = True)

# %%
len(data)
# Out:
# 182

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 182 entries, 1 to 889
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     182 non-null    int64
#  1   pclass       182 non-null    int64
#  2   sex          182 non-null    object
#  3   age          182 non-null    float64
#  4   sibsp        182 non-null    int64
#  5   parch        182 non-null    int64
#  6   fare         182 non-null    float64
#  7   embarked     182 non-null    object
#  8   class        182 non-null    category
#  9   who          182 non-null    object
#  10  adult_male   182 non-null    bool
#  11  deck         182 non-null    category
#  12  embark_town  182 non-null    object
#  13  alone        182 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(4)
# memory usage: 16.8+ KB

# %%
from sklearn.preprocessing import LabelEncoder
lst =["category","object","bool"]
for i in data.columns:
    if data[i].dtype == "category"or data[i].dtype == "object" or data[i].dtype == "bool":
        le = LabelEncoder()
        data[i] = le.fit_transform(data[i])

# %%
data
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare  embarked  class  who  \
# 1           1       1    0  38.0      1      0  71.2833         0      0    2
# 3           1       1    0  35.0      1      0  53.1000         2      0    2
# 6           0       1    1  54.0      0      0  51.8625         2      0    1
# 10          1       3    0   4.0      1      1  16.7000         2      2    0
# 11          1       1    0  58.0      0      0  26.5500         2      0    2
# ..        ...     ...  ...   ...    ...    ...      ...       ...    ...  ...
# 871         1       1    0  47.0      1      1  52.5542         2      0    2
# 872         0       1    1  33.0      0      0   5.0000         2      0    1
# 879         1       1    0  56.0      0      1  83.1583         0      0    2
# 887         1       1    0  19.0      0      0  30.0000         2      0    2
# 889         1       1    1  26.0      0      0  30.0000         0      0    1
#
#      adult_male  deck  embark_town  alone
# 1             0     2            0      0
# 3             0     2            2      0
# 6             1     4            2      1
# 10            0     6            2      0
# 11            0     2            2      1
# ..          ...   ...          ...    ...
# 871           0     3            2      0
# 872           1     1            2      1
# 879           0     2            0      0
# 887           0     1            2      1
# 889           1     2            0      1
#
# [182 rows x 14 columns]

# %%
x =  data.drop(["survived"],axis =1)
y = data["survived"]

# %%
x
# Out:
#      pclass  sex   age  sibsp  parch     fare  embarked  class  who  \
# 1         1    0  38.0      1      0  71.2833         0      0    2
# 3         1    0  35.0      1      0  53.1000         2      0    2
# 6         1    1  54.0      0      0  51.8625         2      0    1
# 10        3    0   4.0      1      1  16.7000         2      2    0
# 11        1    0  58.0      0      0  26.5500         2      0    2
# ..      ...  ...   ...    ...    ...      ...       ...    ...  ...
# 871       1    0  47.0      1      1  52.5542         2      0    2
# 872       1    1  33.0      0      0   5.0000         2      0    1
# 879       1    0  56.0      0      1  83.1583         0      0    2
# 887       1    0  19.0      0      0  30.0000         2      0    2
# 889       1    1  26.0      0      0  30.0000         0      0    1
#
#      adult_male  deck  embark_town  alone
# 1             0     2            0      0
# 3             0     2            2      0
# 6             1     4            2      1
# 10            0     6            2      0
# 11            0     2            2      1
# ..          ...   ...          ...    ...
# 871           0     3            2      0
# 872           1     1            2      1
# 879           0     2            0      0
# 887           0     1            2      1
# 889           1     2            0      1
#
# [182 rows x 13 columns]

# %%
y
# Out:
# 1      1
# 3      1
# 6      0
# 10     1
# 11     1
#       ..
# 871    1
# 872    0
# 879    1
# 887    1
# 889    1
# Name: survived, Length: 182, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.20,random_state=1)

# %%
X_train
# Out:
#      pclass  sex   age  sibsp  parch      fare  embarked  class  who  \
# 857       1    1  51.0      0      0   26.5500         2      0    1
# 782       1    1  29.0      0      0   30.0000         2      0    1
# 581       1    0  39.0      1      1  110.8833         0      0    2
# 587       1    1  60.0      1      1   79.2000         0      0    1
# 765       1    0  51.0      1      0   77.9583         2      0    2
# ..      ...  ...   ...    ...    ...       ...       ...    ...  ...
# 659       1    1  58.0      0      2  113.2750         0      0    1
# 681       1    1  27.0      0      0   76.7292         0      0    1
# 356       1    0  22.0      0      1   55.0000         2      0    2
# 698       1    1  49.0      1      1  110.8833         0      0    1
# 218       1    0  32.0      0      0   76.2917         0      0    2
#
#      adult_male  deck  embark_town  alone
# 857           1     4            2      1
# 782           1     3            2      1
# 581           0     2            0      0
# 587           1     1            0      0
# 765           0     3            2      0
# ..          ...   ...          ...    ...
# 659           1     3            0      0
# 681           1     3            0      1
# 356           0     4            2      0
# 698           1     2            0      0
# 218           0     3            0      1
#
# [145 rows x 13 columns]

# %%
Y_train
# Out:
# 857    1
# 782    0
# 581    1
# 587    1
# 765    1
#       ..
# 659    0
# 681    1
# 356    1
# 698    0
# 218    1
# Name: survived, Length: 145, dtype: int64

# %%
X_test
# Out:
#      pclass  sex   age  sibsp  parch      fare  embarked  class  who  \
# 297       1    0   2.0      1      2  151.5500         2      0    0
# 456       1    1  65.0      0      0   26.5500         2      0    1
# 512       1    1  36.0      0      0   26.2875         2      0    1
# 571       1    0  53.0      2      0   51.4792         2      0    2
# 268       1    0  58.0      0      1  153.4625         2      0    2
# 796       1    0  49.0      0      0   25.9292         2      0    2
# 193       2    1   3.0      1      1   26.0000         2      1    0
# 430       1    1  28.0      0      0   26.5500         2      0    1
# 544       1    1  50.0      1      0  106.4250         0      0    1
# 585       1    0  18.0      0      2   79.6500         2      0    2
# 97        1    1  23.0      0      1   63.3583         0      0    1
# 871       1    0  47.0      1      1   52.5542         2      0    2
# 492       1    1  55.0      0      0   30.5000         2      0    1
# 66        2    0  29.0      0      0   10.5000         2      1    2
# 393       1    0  23.0      1      0  113.2750         0      0    2
# 11        1    0  58.0      0      0   26.5500         2      0    2
# 473       2    0  23.0      0      0   13.7917         0      1    2
# 92        1    1  46.0      1      0   61.1750         2      0    1
# 177       1    0  50.0      0      0   28.7125         0      0    2
# 118       1    1  24.0      0      1  247.5208         0      0    1
# 647       1    1  56.0      0      0   35.5000         0      0    1
# 558       1    0  39.0      1      1   79.6500         2      0    2
# 609       1    0  40.0      0      0  153.4625         2      0    2
# 453       1    1  49.0      1      0   89.1042         0      0    1
# 269       1    0  35.0      0      0  135.6333         2      0    2
# 781       1    0  17.0      1      0   57.0000         2      0    2
# 429       3    1  32.0      0      0    8.0500         2      2    1
# 307       1    0  17.0      1      0  108.9000         0      0    2
# 251       3    0  29.0      1      1   10.4625         2      2    2
# 435       1    0  14.0      1      2  120.0000         2      0    0
# 583       1    1  36.0      0      0   40.1250         0      0    1
# 209       1    1  40.0      0      0   31.0000         0      0    1
# 245       1    1  44.0      2      0   90.0000         1      0    1
# 311       1    0  18.0      2      2  262.3750         0      0    2
# 102       1    1  21.0      0      1   77.2875         2      0    1
# 21        2    1  34.0      0      0   13.0000         2      1    1
# 806       1    1  39.0      0      0    0.0000         2      0    1
#
#      adult_male  deck  embark_town  alone
# 297           0     2            2      0
# 456           1     4            2      1
# 512           1     4            2      1
# 571           0     2            2      0
# 268           0     2            2      0
# 796           0     3            2      1
# 193           0     5            2      0
# 430           1     2            2      1
# 544           1     2            0      0
# 585           0     4            2      0
# 97            1     3            0      0
# 871           0     3            2      0
# 492           1     2            2      1
# 66            0     5            2      1
# 393           0     3            0      0
# 11            0     2            2      1
# 473           0     3            0      1
# 92            1     4            2      0
# 177           0     2            0      1
# 118           1     1            0      0
# 647           1     0            0      1
# 558           0     4            2      0
# 609           0     2            2      1
# 453           1     2            0      0
# 269           0     2            2      1
# 781           0     1            2      0
# 429           1     4            2      1
# 307           0     2            0      0
# 251           0     6            2      0
# 435           0     1            2      0
# 583           1     0            0      1
# 209           1     0            0      1
# 245           1     2            1      0
# 311           0     1            0      0
# 102           1     3            2      0
# 21            1     3            2      1
# 806           1     0            2      1

# %%
Y_test
# Out:
# 297    0
# 456    0
# 512    1
# 571    1
# 268    1
# 796    1
# 193    1
# 430    1
# 544    0
# 585    1
# 97     1
# 871    1
# 492    0
# 66     1
# 393    1
# 11     1
# 473    1
# 92     0
# 177    0
# 118    0
# 647    1
# 558    1
# 609    1
# 453    1
# 269    1
# 781    1
# 429    1
# 307    1
# 251    0
# 435    1
# 583    0
# 209    1
# 245    0
# 311    1
# 102    0
# 21     1
# 806    0
# Name: survived, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
model.score(X_train,Y_train)
# Out:
# 1.0

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
we =model.predict(X_test)

# %%
a  = accuracy_score(Y_test,we)

# %%
a
# Out:
# 0.6756756756756757
